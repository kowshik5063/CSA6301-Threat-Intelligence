# %% [markdown]
# <a href="https://colab.research.google.com/github/PadmaPrabhasKorsipati/CSA63-Threat-Intelligence-and-Network-Security/blob/main/Lab/Unit%201%20Experiments/LAB_08_DICTIONARY_ATTACK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dictionary Attack Demo
import hashlib

# Simulate a stolen password hash
# (A real system would never expose this!)
stolen_hash = hashlib.sha256("letmein".encode()).hexdigest()

wordlist = ["123456", "password", "admin", "letmein", "qwerty"]

print("Attempting dictionary attack on stolen hash...")

found = False

for word in wordlist:
    guess_hash = hashlib.sha256(word.encode()).hexdigest()

    if guess_hash == stolen_hash:
        print(f"Password cracked: '{word}'")
        found = True
        break

if not found:
    print("Password not found in wordlist.")
# Out:
# Attempting dictionary attack on stolen hash...
# Password cracked: 'letmein'
